# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('country_price_by_month.csv',encoding='1251')
df.shape
# Out:
# (34728, 9)

# %%
df.head(3)
# Out:
#   iata    name country       country_name  departMonth precipitation price  \
# 0  SHW  Шарура      SA  Саудовская Аравия            1          None  None
# 1  SHW  Шарура      SA  Саудовская Аравия            2          None  None
# 2  SHW  Шарура      SA  Саудовская Аравия            3          None  None
#
#   season temperature
# 0      1     19.4701
# 1      5     23.3231
# 2   None     28.0568

# %%
df['price'].value_counts()
# Out:
# None       29876
# 3500.0        41
# 4200.0        38
# 3800.0        38
# 4500.0        37
#            ...
# 91700.0        1
# 66800.0        1
# 61500.0        1
# 62800.0        1
# 72400.0        1
# Name: price, Length: 714, dtype: int64

# %%
df[df['price'] != 'None'].shape
# Out:
# (4852, 9)

# %%
df = df[df['price'] != 'None']

# %%
df.head(3)
# Out:
#      iata    name country country_name  departMonth precipitation    price  \
# 2016  GNJ  Гянджа      AZ  Азербайджан            1          None  12600.0
# 2017  GNJ  Гянджа      AZ  Азербайджан            2          None  10300.0
# 2018  GNJ  Гянджа      AZ  Азербайджан            3          None  10600.0
#
#      season temperature
# 2016   None        None
# 2017   None        None
# 2018   None        None

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4852 entries, 2016 to 34547
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   iata           4852 non-null   object
#  1   name           4852 non-null   object
#  2   country        4852 non-null   object
#  3   country_name   4852 non-null   object
#  4   departMonth    4852 non-null   int64
#  5   precipitation  4852 non-null   object
#  6   price          4852 non-null   object
#  7   season         4852 non-null   object
#  8   temperature    4852 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 379.1+ KB

# %%
df['price'] = df['price'].astype(np.float64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4852 entries, 2016 to 34547
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   iata           4852 non-null   object
#  1   name           4852 non-null   object
#  2   country        4852 non-null   object
#  3   country_name   4852 non-null   object
#  4   departMonth    4852 non-null   int64
#  5   precipitation  4852 non-null   object
#  6   price          4852 non-null   float64
#  7   season         4852 non-null   object
#  8   temperature    4852 non-null   object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 379.1+ KB

# %%
df[df['country_name'] != 'Россия'].sort_values('price').head(200)['country_name'].value_counts()
# Out:
# Италия                27
# Германия              19
# Таджикистан           13
# Крым                  12
# Чехия                 12
# Беларусь              12
# Венгрия               11
# Словакия               8
# Бельгия                8
# Франция                6
# Израиль                6
# Армения                6
# Кыргызстан             6
# Испания                6
# Узбекистан             6
# Иордания               5
# Нидерланды             5
# Латвия                 5
# Азербайджан            5
# Австрия                3
# Болгария               3
# Греция                 3
# Тунис                  2
# Марокко                2
# Молдова                2
# Казахстан              2
# ОАЭ                    2
# Турция                 1
# Северная Македония     1
# Хорватия               1
# Name: country_name, dtype: int64

# %%
df[(df['country_name'] == 'Италия') & df['departMonth'].isin([10,11,12]) ].sort_values('price').head(200)
# Out:
#      iata           name country country_name  departMonth precipitation  \
# 8841  SUF  Ламеция-Терме      IT       Италия           10          None
# 8950  RMI         Римини      IT       Италия           11          None
# 8793  GOA          Генуя      IT       Италия           10          None
# 8915  PSA           Пиза      IT       Италия           12          None
# 8914  PSA           Пиза      IT       Италия           11          None
# 8951  RMI         Римини      IT       Италия           12          None
# 8949  RMI         Римини      IT       Италия           10          None
# 8913  PSA           Пиза      IT       Италия           10          None
# 8805  CAG        Кальяри      IT       Италия           10          None
# 8985  TRN          Турин      IT       Италия           10          None
# 8794  GOA          Генуя      IT       Италия           11          None
# 8783  VRN         Верона      IT       Италия           12          None
# ...

# %%
df[(df['country_name'] == 'Ереван') & df['departMonth'].isin([10,11,12]) ].sort_values('price').head(200)
# Out:
# Empty DataFrame
# Columns: [iata, name, country, country_name, departMonth, precipitation, price, season, temperature]
# Index: []

# %%
df[(df['name'] == 'Ереван')].sort_values('departMonth')[['departMonth','price']]#.plot(kind='bar',y='price',x='departMonth')
# Out:
#       departMonth    price
# 6264            1   6800.0
# 6265            2   6500.0
# 6266            3  11300.0
# 6267            4  13300.0
# 6268            5  11900.0
# 6269            6  13700.0
# 6270            7  15300.0
# 6271            8  10500.0
# 6272            9  11500.0
# 6273           10  13600.0
# 6274           11   9400.0
# 6275           12  10300.0
